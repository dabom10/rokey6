# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/rokey
# Out:
# /content/drive/MyDrive/rokey

# %%
# !git config --global user.email "dabom425@gmail.com"
# !git config --global user.name "dabom10"

# %%
# !git add -A

# %%
# !git commit -m "openCV - 영상처리 기본, 필터, 특징검출"
# Out:
# [main 00c6dea] openCV - 영상처리 기본, 필터, 특징검출
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Untitled0.ipynb (76%)

# %%
# !git push
# Out:
# Enumerating objects: 25, done.
# Counting objects: 100% (25/25), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (20/20), done.
# Writing objects: 100% (20/20), 280.58 MiB | 9.06 MiB/s, done.
# Total 20 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 1 local object.
# remote: error: Trace: 585034c4f70af99728068e0f14730b1f68ae608ef0dae4b041ea6a664b95bb0d
# remote: error: See https://gh.io/lfs for more information.
# remote: error: File AI/application/3/(코드1)강의_6기_AI응용_3차시_01_로컬동영상 기본.ipynb is 333.72 MB; this exceeds GitHub's file size limit of 100.00 MB
# remote: error: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# To https://github.com/dabom10/rokey6.git
#  ! [remote rejected] main -> main (pre-receive hook declined)
# error: failed to push some refs to 'https://github.com/dabom10/rokey6.git'
