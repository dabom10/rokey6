# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/rokey
# Out:
# /content/drive/MyDrive/rokey

# %%
# !git config --global user.email "dabom425@gmail.com"
# !git config --global user.name "dabom10"

# %%
# !git add -A

# %%
# !git commit -m "AI 응용 6"
# Out:
# [main f38dca4] 루카스 카나데 추적-frame update error
#  3 files changed, 3 insertions(+), 287 deletions(-)
#  rewrite "AI/application/5/(\341\204\217\341\205\251\341\204\203\341\205\2633)\341\204\200\341\205\241\341\206\274\341\204\213\341\205\264_6\341\204\200\341\205\265_AI\341\204\213\341\205\263\341\206\274\341\204\213\341\205\255\341\206\274_5\341\204\216\341\205\241\341\204\211\341\205\265_03_VGG13_pretrained.ipynb" (99%)
#  rewrite Untitled0.ipynb (66%)

# %%
# !git push
# Out:
# Enumerating objects: 17, done.
# Counting objects: 100% (17/17), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 4.83 KiB | 150.00 KiB/s, done.
# Total 9 (delta 6), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (6/6), completed with 6 local objects.
# To https://github.com/dabom10/rokey6.git
#    f87736c..f38dca4  main -> main
