# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/rokey
# Out:
# /content/drive/MyDrive/rokey

# %%
# !git config --global user.email "dabom425@gmail.com"
# !git config --global user.name "dabom10"

# %%
# !git add -A

# %%
# !git commit -m "AI 응용-3d Rendering:NeRF"
# Out:
# [main 92812be] AI 응용-3d Rendering:NeRF
#  4 files changed, 2593 insertions(+), 3 deletions(-)
#  rewrite "AI/application/7/(\341\204\217\341\205\251\341\204\203\341\205\2632)\341\204\200\341\205\241\341\206\274\341\204\213\341\205\264_6\341\204\200\341\205\265_AI\341\204\213\341\205\263\341\206\274\341\204\213\341\205\255\341\206\274_7\341\204\216\341\205\241\341\204\211\341\205\265_02_pix2pix.ipynb" (96%)
#  rewrite "AI/application/8/(\341\204\217\341\205\251\341\204\203\341\205\2632)\341\204\200\341\205\241\341\206\274\341\204\213\341\205\264_6\341\204\200\341\205\265_AI\341\204\213\341\205\263\341\206\274\341\204\213\341\205\255\341\206\274_8\341\204\216\341\205\241\341\204\211\341\205\265_02_image_captioning_beginner_cnn_lstm.ipynb" (98%)
#  create mode 100644 "AI/application/9/\341\204\200\341\205\241\341\206\274\341\204\213\341\205\264_6\341\204\200\341\205\265_AI\341\204\213\341\205\263\341\206\274\341\204\213\341\205\255\341\206\274_9\341\204\216\341\205\241\341\204\211\341\205\265_01_tiny_nerf_.ipynb"

# %%
# !git push
# Out:
# Enumerating objects: 19, done.
# Counting objects: 100% (19/19), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (11/11), done.
# Writing objects: 100% (11/11), 11.62 MiB | 9.86 MiB/s, done.
# Total 11 (delta 5), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (5/5), completed with 5 local objects.
# To https://github.com/dabom10/rokey6.git
#    6e44558..92812be  main -> main
