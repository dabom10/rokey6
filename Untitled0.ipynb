# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/rokey
# Out:
# /content/drive/MyDrive/rokey

# %%
# !git config --global user.email "dabom425@gmail.com"
# !git config --global user.name "dabom10"

# %%
# !git add -A

# %%
# !git commit -m "루카스 카나데 추적 및 NST"
# Out:
# [main f87736c] 루카스 카나데 추적 및 NST
#  7 files changed, 289 insertions(+), 1 deletion(-)
#  create mode 100644 "AI/application/4/(\341\204\217\341\205\251\341\204\203\341\205\2636)\341\204\200\341\205\241\341\206\274\341\204\213\341\205\264_6\341\204\200\341\205\265_AI\341\204\213\341\205\263\341\206\274\341\204\213\341\205\255\341\206\274_4\341\204\216\341\205\241\341\204\211\341\205\265_07_Lucas_Kanade.ipynb"
#  create mode 100644 "AI/application/6/(\341\204\217\341\205\251\341\204\203\341\205\2631)\341\204\200\341\205\241\341\206\274\341\204\213\341\205\264_6\341\204\200\341\205\265_AI\341\204\213\341\205\263\341\206\274\341\204\213\341\205\255\341\206\274_6\341\204\216\341\205\241\341\204\211\341\205\265_01_GramMatrix\341\204\213\341\205\252 Loss.ipynb"
#  create mode 100644 "AI/application/6/(\341\204\217\341\205\251\341\204\203\341\205\2632)\341\204\200\341\205\241\341\206\274\341\204\213\341\205\264_6\341\204\200\341\205\265_AI\341\204\213\341\205\263\341\206\274\341\204\213\341\205\255\341\206\274_6\341\204\216\341\205\241\341\204\211\341\205\265_02_neural_style_transfer.ipynb"
#  create mode 100644 "AI/application/6/6\341\204\216\341\205\241\341\204\211\341\205\265 \341\204\213\341\205\265\341\204\205\341\205\251\341\206\253.ipynb"
#  create mode 100644 AI/application/6/Tuebingen_Neckarfront.jpg
#  create mode 100644 AI/application/6/vangogh_starry_night.jpg
#  rewrite Untitled0.ipynb (95%)

# %%
# !git push
# Out:
# Enumerating objects: 18, done.
# Counting objects: 100% (18/18), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (13/13), done.
# Writing objects: 100% (13/13), 17.52 MiB | 10.21 MiB/s, done.
# Total 13 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/dabom10/rokey6.git
#    f6ce902..f87736c  main -> main
