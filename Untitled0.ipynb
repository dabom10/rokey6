# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/rokey
# Out:
# /content/drive/MyDrive/rokey

# %%
# !git config --global user.email "dabom425@gmail.com"
# !git config --global user.name "dabom10"

# %%
# !git add -A

# %%
# !git commit -m "ros2 install"
# Out:
# [main 9a5cef5] server-client connecting code
#  19 files changed, 648 insertions(+), 1 deletion(-)
#  create mode 100644 "AI/application/\341\204\200\341\205\252\341\204\214\341\205\246/DR-06004_\341\204\200\341\205\265\341\206\267\341\204\203\341\205\241\341\204\207\341\205\251\341\206\267_\341\204\217\341\205\245\341\206\267\341\204\221\341\205\262\341\204\220\341\205\245\341\204\207\341\205\265\341\204\214\341\205\245\341\206\253\341\204\213\341\205\263\341\206\274\341\204\213\341\205\255\341\206\274_13\341\204\216\341\205\241\341\204\211\341\205\265.ipynb"
#  create mode 100644 ROS2/ROS2_basic/argsExample1.py
#  create mode 100644 ROS2/ROS2_basic/argsExample2.py
#  create mode 100644 ROS2/ROS2_basic/argsExample3.py
#  create mode 100644 ROS2/ROS2_basic/chattingClient.py
#  create mode 100644 ROS2/ROS2_basic/chattingClient1.py
#  create mode 100644 ROS2/ROS2_basic/chattingServer.py
#  create mode 100644 ROS2/ROS2_basic/fileReceive.py
#  create mode 100644 ROS2/ROS2_basic/fileSend.py
#  create mode 100644 ROS2/ROS2_basic/sendfile.txt
#  create mode 100644 ROS2/ROS2_basic/socketClient.py
#  create mode 100644 ROS2/ROS2_basic/socketServer.py
#  create mode 100644 ROS2/ROS2_basic/subprocess1.py
#  create mode 100644 ROS2/ROS2_basic/subprocesslinux.py
#  create mode 100644 ROS2/ROS2_basic/tcpClient.py
#  create mode 100644 ROS2/ROS2_basic/tcpServer.py
#  create mode 100644 ROS2/ROS2_basic/udpClient.py
#  create mode 100644 ROS2/ROS2_basic/udpServer.py
#  rewrite Untitled0.ipynb (77%)

# %%
# !git push
# Out:
# Enumerating objects: 31, done.
# Counting objects: 100% (31/31), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (24/24), done.
# Writing objects: 100% (26/26), 10.23 KiB | 161.00 KiB/s, done.
# Total 26 (delta 7), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (7/7), completed with 3 local objects.
# To https://github.com/dabom10/rokey6.git
#    befe55b..9a5cef5  main -> main
