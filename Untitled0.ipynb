# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/rokey
# Out:
# /content/drive/MyDrive/rokey

# %%
# !git config --global user.email "dabom425@gmail.com"
# !git config --global user.name "dabom10"

# %%
# !git add -A

# %%
# !git commit -m "AI 응용 - object detection"
# Out:
# [main 99b9e15] AI 응용 - object detection
#  4 files changed, 4 insertions(+), 1 deletion(-)
#  create mode 100644 "AI/application/12/(\341\204\217\341\205\251\341\204\203\341\205\2631)\341\204\200\341\205\241\341\206\274\341\204\213\341\205\264_6\341\204\200\341\205\265_AI\341\204\213\341\205\263\341\206\274\341\204\213\341\205\255\341\206\274_12\341\204\216\341\205\241\341\204\211\341\205\265_01_Object_Detection_Beginner.ipynb"
#  create mode 100644 "AI/application/12/(\341\204\217\341\205\251\341\204\203\341\205\2632)\341\204\200\341\205\241\341\206\274\341\204\213\341\205\264_6\341\204\200\341\205\265_AI\341\204\213\341\205\263\341\206\274\341\204\213\341\205\255\341\206\274_12\341\204\216\341\205\241\341\204\211\341\205\265_02_Object_Detection_Adv.ipynb"
#  create mode 100644 "AI/application/12/(\341\204\217\341\205\251\341\204\203\341\205\2633)\341\204\200\341\205\241\341\206\274\341\204\213\341\205\264_6\341\204\200\341\205\265_AI\341\204\213\341\205\263\341\206\274\341\204\213\341\205\255\341\206\274_12\341\204\216\341\205\241\341\204\211\341\205\265_03_Object_Detection_SSD Object Detection_basic.ipynb"
#  rewrite Untitled0.ipynb (86%)

# %%
# !git push
# Out:
# Enumerating objects: 13, done.
# Counting objects: 100% (13/13), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 6.58 MiB | 8.89 MiB/s, done.
# Total 9 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/dabom10/rokey6.git
#    6e63aaf..99b9e15  main -> main
