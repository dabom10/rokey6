# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/rokey
# Out:
# /content/drive/MyDrive/rokey

# %%
# !git config --global user.email "dabom425@gmail.com"
# !git config --global user.name "dabom10"

# %%
# !git add -A

# %%
# !git commit -m "openCV - 5"
# Out:
# [main 49b1ec8] openCV - 4차시 이론 정리
#  4 files changed, 4 insertions(+), 3 deletions(-)
#  rewrite "AI/application/3/(\341\204\217\341\205\251\341\204\203\341\205\2633)\341\204\200\341\205\241\341\206\274\341\204\213\341\205\264_6\341\204\200\341\205\265_AI\341\204\213\341\205\263\341\206\274\341\204\213\341\205\255\341\206\274_3\341\204\216\341\205\241\341\204\211\341\205\265_03_\341\204\213\341\205\265\341\204\214\341\205\265\341\206\253\341\204\222\341\205\252\341\204\213\341\205\252 \341\204\220\341\205\263\341\206\250\341\204\214\341\205\265\341\206\274 \341\204\200\341\205\245\341\206\267\341\204\216\341\205\256\341\206\257.ipynb" (73%)
#  create mode 100644 "AI/application/4/4\341\204\216\341\205\241\341\204\211\341\205\265 \341\204\200\341\205\241\341\206\274\341\204\213\341\205\264 \341\204\213\341\205\265\341\204\205\341\205\251\341\206\253.ipynb"
#  rewrite Untitled0.ipynb (86%)

# %%
# !git push
# Out:
# Enumerating objects: 18, done.
# Counting objects: 100% (18/18), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (10/10), done.
# Writing objects: 100% (10/10), 4.04 KiB | 111.00 KiB/s, done.
# Total 10 (delta 5), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (5/5), completed with 5 local objects.
# To https://github.com/dabom10/rokey6.git
#    4c7b388..49b1ec8  main -> main
