# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/rokey
# Out:
# /content/drive/MyDrive/rokey

# %%
# !git config --global user.email "dabom425@gmail.com"
# !git config --global user.name "dabom10"

# %%
# !git add -A

# %%
# !git commit -m "ros2 과제"
# Out:
# [main 40ed207] ros2 install
#  3 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 "ROS2/install/ROS\341\204\211\341\205\245\341\206\257\341\204\216\341\205\265\341\204\221\341\205\241\341\204\213\341\205\265\341\206\257.zip"
#  create mode 100644 "ROS2/install/terminal \341\204\211\341\205\265\341\206\257\341\204\222\341\205\242\341\206\274 \341\204\217\341\205\251\341\204\203\341\205\263.ipynb"
#  rewrite Untitled0.ipynb (67%)

# %%
# !git push
# Out:
# Enumerating objects: 10, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 4.07 KiB | 148.00 KiB/s, done.
# Total 7 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/dabom10/rokey6.git
#    9a5cef5..40ed207  main -> main
