# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/rokey
# Out:
# /content/drive/MyDrive/rokey

# %%
# !git config --global user.email "dabom425@gmail.com"
# !git config --global user.name "dabom10"

# %%
# !git add -A

# %%
# !git commit -m "openCV - 추적 알고리즘Object Tracking : Template Matching, MeanShift/CamShift, Sparse Optical Flow, Dense Optical Flow"
# Out:
# [main 4c7b388] openCV - 추적 알고리즘Object Tracking : Template Matching, MeanShift/CamShift, Sparse Optical Flow, Dense Optical Flow
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite "AI/application/4/(\341\204\217\341\205\251\341\204\203\341\205\2633) \341\204\200\341\205\241\341\206\274\341\204\213\341\205\264_6\341\204\200\341\205\265_AI\341\204\213\341\205\263\341\206\274\341\204\213\341\205\255\341\206\274_4\341\204\216\341\205\241\341\204\211\341\205\265_03_optical_flow.ipynb" (98%)
#  rewrite Untitled0.ipynb (78%)

# %%
# !git push
# Out:
# Enumerating objects: 13, done.
# Counting objects: 100% (13/13), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 2.24 KiB | 71.00 KiB/s, done.
# Total 7 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/dabom10/rokey6.git
#    f180736..4c7b388  main -> main
