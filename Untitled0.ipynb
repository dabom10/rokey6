# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/rokey
# Out:
# /content/drive/MyDrive/rokey

# %%
# !git config --global user.email "dabom425@gmail.com"
# !git config --global user.name "dabom10"

# %%
# !git add -A

# %%
# !git commit -m "AI 응용 - 강화학습"
# Out:
# [main e9de9a5] AI 응용 - 강화학습
#  4 files changed, 267 insertions(+), 1 deletion(-)
#  create mode 100644 "AI/application/13/(\341\204\217\341\205\251\341\204\203\341\205\2631)\341\204\200\341\205\241\341\206\274\341\204\213\341\205\264_6\341\204\200\341\205\265_AI\341\204\213\341\205\263\341\206\274\341\204\213\341\205\255\341\206\274_13\341\204\216\341\205\241\341\204\211\341\205\265_01_Reinforcement_Learning_Beginner.ipynb"
#  create mode 100644 "AI/application/13/(\341\204\217\341\205\251\341\204\203\341\205\2632)Reinforcement_Algo.ipynb"
#  create mode 100644 "AI/application/\341\204\200\341\205\252\341\204\214\341\205\246/DR-06004_\341\204\200\341\205\265\341\206\267\341\204\203\341\205\241\341\204\207\341\205\251\341\206\267_\341\204\217\341\205\245\341\206\267\341\204\221\341\205\262\341\204\220\341\205\245\341\204\207\341\205\265\341\204\214\341\205\245\341\206\253\341\204\213\341\205\263\341\206\274\341\204\213\341\205\255\341\206\274_12\341\204\216\341\205\241\341\204\211\341\205\265.ipynb"
#  rewrite Untitled0.ipynb (77%)

# %%
# !git push
# Out:
# Enumerating objects: 15, done.
# Counting objects: 100% (15/15), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (10/10), done.
# Writing objects: 100% (10/10), 294.22 KiB | 5.16 MiB/s, done.
# Total 10 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/dabom10/rokey6.git
#    a3bb85d..e9de9a5  main -> main
