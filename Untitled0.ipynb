# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/rokey
# Out:
# /content/drive/MyDrive/rokey

# %%
# !git config --global user.email "dabom425@gmail.com"
# !git config --global user.name "dabom10"

# %%
# !git add -A

# %%
# !git commit -m "ros2 과제"
# Out:
# [main 50a3786] ros2 과제
#  2 files changed, 1 insertion(+), 1 deletion(-)
#  create mode 100644 "ROS2/assignment/DR-06004_\341\204\200\341\205\265\341\206\267\341\204\203\341\205\241\341\204\207\341\205\251\341\206\267_ROS\341\204\211\341\205\265\341\206\257\341\204\211\341\205\263\341\206\270_6\341\204\216\341\205\241\341\204\211\341\205\265.pdf"

# %%
# !git push
# Out:
# Enumerating objects: 10, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 107.04 KiB | 5.63 MiB/s, done.
# Total 6 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/dabom10/rokey6.git
#    2d7486c..50a3786  main -> main
