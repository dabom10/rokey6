# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/rokey
# Out:
# /content/drive/MyDrive/rokey

# %%
# !git config --global user.email "dabom425@gmail.com"
# !git config --global user.name "dabom10"

# %%
# !git add -A

# %%
# !git commit -m "update-2"
# Out:
# [main 33481d5] update-2
#  4 files changed, 4788 insertions(+)
#  create mode 100644 AI/application/2/advanced_yolo_tutorial.ipynb
#  create mode 100644 AI/application/2/finetuning_tutorial.ipynb
#  create mode 100644 AI/application/2/multi_layer_tutorial.ipynb
#  create mode 100644 AI/application/2/yolo_detector_tutorial.ipynb

# %%
# !git push
# Out:
# Enumerating objects: 12, done.
# Counting objects: 100% (12/12), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 42.53 KiB | 1.63 MiB/s, done.
# Total 9 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), done.
# To https://github.com/dabom10/rokey6.git
#    7054bb6..33481d5  main -> main
