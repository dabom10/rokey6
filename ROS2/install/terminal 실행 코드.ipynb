# %%
# ubuntu 버전 확인
lsb_release -a

# Ubuntu 22.04.4 LTS

# %%
# ros 설치파일 압축 풀고 설치 시작

# 우분투 버전 확인
lsb_release -a

# 설치 경로로 이동
cd ~/downloads

# 필요한 모듈 설치

# git install
sudo apt update
sudo apt install git

# 권한부여
chmod +x ros2-humble-desktop-main.sh

# ros-2 설치
./ros2-humble-desktop-main.sh

# %%
# 설치 확인

# 권한부여
chmod +x  ./tutorial.sh

# 설치 확인
./tutorial.sh

# %%
# 터미널에 아래 문구 뜨고 화면 업데이트 안되면 설치 완료된 것

# Finished <<< launch_testing_examples

# Summary: 22 packages finished

# %%
# 새로운 터미널에서 아래 명령어 실행

ros2 run examples_rclcpp_minimal_publisher publisher_member_function

# 동작 확인 종료 방법 키보드: ctrl + c

# %%
# ros 버전 확인

printenv ROS_DISTRO

# humble
